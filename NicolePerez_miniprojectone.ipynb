# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics, linear_model, model_selection
from sklearn.metrics import r2_score, mean_squared_error, mean_squared_log_error, mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('melon.csv')
df.head()
# Out:
#    Weight  Price
# 0       1     50
# 1       2    100
# 2       3    140
# 3       4    180
# 4       5    220

# %%
df.info
# Out:
# <bound method DataFrame.info of    Weight  Price
# 0       1     50
# 1       2    100
# 2       3    140
# 3       4    180
# 4       5    220
# 5       6    250
# 6       7    300
# 7       8    340
# 8       9    380
# 9      10    390>

# %%
df.isnull().sum()
# Out:
# Weight    0
# Price     0
# dtype: int64

# %%
df.shape
# Out:
# (10, 2)

# %%
df.describe()
# Out:
#          Weight       Price
# count  10.00000   10.000000
# mean    5.50000  235.000000
# std     3.02765  117.968922
# min     1.00000   50.000000
# 25%     3.25000  150.000000
# 50%     5.50000  235.000000
# 75%     7.75000  330.000000
# max    10.00000  390.000000

# %%
plt.figure(figsize=(5,3))

plt.scatter(df['Weight'],df['Price'], c='green') 
plt.title("Relationship between Weight and Price of Watermelon")
plt.xlabel('weight')
plt.ylabel('price')

plt.show()

# %% [raw]
# Linear Regression (sklearn)

# %%
# Split the dataset 
weight = df['Weight']
price = df['Price']

#shape of the data 
weight = weight.values.reshape(-1,1)
price = price.values.reshape(-1,1)

# %%
#import scikit learn
from sklearn import linear_model

# Linear regressor 
regr = linear_model.LinearRegression()


regr.fit(weight, price)
# Out:
# LinearRegression()

# %%
a = regr.predict(weight)

# %%
a
# Out:
# array([[ 60.18181818],
#        [ 99.03030303],
#        [137.87878788],
#        [176.72727273],
#        [215.57575758],
#        [254.42424242],
#        [293.27272727],
#        [332.12121212],
#        [370.96969697],
#        [409.81818182]])

# %%
from sklearn.metrics import mean_squared_error, r2_score

print("Mean Squared Error ", mean_squared_error(price, z))
print("r2 coefficient", r2_score(price,z))
# Out:
# Mean Squared Error  74.06060606060605
# r2 coefficient 0.9940869775600315

# %%
import matplotlib.pyplot as plt

plt.scatter(weight, price,color="black")
plt.plot(weight,z,color="green")
plt.xlabel("Weight of watermelon")
plt.ylabel("Price of watermelon")

plt.show()
